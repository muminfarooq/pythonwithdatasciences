# %%
import pandas as pd

# %%
df=pd.read_csv('e://myfiles//population_india_census2011.csv')

# %%
df.head(2)
# Out:
#    Sno State / Union Territory  Population  Rural population  \
# 0    1           Uttar Pradesh   199812341         155317278
# 1    2             Maharashtra   112374333          61556074
#
#    Urban population                         Area                Density  \
# 0          44495063   240,928 km2 (93,023 sq mi)  828/km2 (2,140/sq mi)
# 1          50818259  307,713 km2 (118,809 sq mi)    365/km2 (950/sq mi)
#
#    Gender Ratio
# 0           912
# 1           929

# %%
df.columns
# Out:
# Index(['Sno', 'State / Union Territory', 'Population', 'Rural population',
#        'Urban population', 'Area', 'Density', 'Gender Ratio'],
#       dtype='object')

# %%
c_=df.columns.values

# %%
c_[1]
# Out:
# 'State / Union Territory'

# %%
c_[1]='Region'

# %%
df.head(2)
# Out:
#    Sno         Region  Population  Rural population  Urban population  \
# 0    1  Uttar Pradesh   199812341         155317278          44495063
# 1    2    Maharashtra   112374333          61556074          50818259
#
#                           Area                Density  Gender Ratio
# 0   240,928 km2 (93,023 sq mi)  828/km2 (2,140/sq mi)           912
# 1  307,713 km2 (118,809 sq mi)    365/km2 (950/sq mi)           929

# %%
df.shape
# Out:
# (36, 8)

# %% [markdown]
# # total population

# %%
df['Population'].sum()
# Out:
# 1210568111

# %%
df['Rural population'].sum()
# Out:
# 833521087

# %%
df['Urban population'].sum()
# Out:
# 377047024

# %%
df.columns.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Index(['Sno', 'Region', 'Population', 'Rural population', 'Urban population',
#        'Area', 'Density', 'Gender Ratio'],
#       dtype='object')>

# %%
df_c=df.groupby('Area')['Population','Rural population','Urban population']
# Out:
# C:\Users\Mumin\New folder\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#    Sno          Region  Population  Rural population  Urban population  \
# 0    1   Uttar Pradesh   199812341         155317278          44495063
# 1    2     Maharashtra   112374333          61556074          50818259
# 2    3           Bihar   104099452          92341436          11758016
# 3    4     West Bengal    91276115          62183113          29093002
# 4    5  Madhya Pradesh    72626809          52557404          20069405
#
#                           Area                  Density  Gender Ratio
# 0   240,928 km2 (93,023 sq mi)    828/km2 (2,140/sq mi)           912
# 1  307,713 km2 (118,809 sq mi)      365/km2 (950/sq mi)           929
# 2    94,163 km2 (36,357 sq mi)  1,102/km2 (2,850/sq mi)           918
# 3    88,752 km2 (34,267 sq mi)  1,029/km2 (2,670/sq mi)           953
# 4  308,245 km2 (119,014 sq mi)      236/km2 (610/sq mi)           931

# %%
df['Region']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\New folder\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-bb03e3f2ed53> in <module>
# ----> 1 df['Region']
#
# ...

# %%
df.iloc[23]
# Out:
# Sno                                       24
# Region                              Nagaland
# Population                           1978502
# Rural population                     1407536
# Urban population                      570966
# Area                16,579 km2 (6,401 sq mi)
# Density                  119/km2 (310/sq mi)
# Gender Ratio                             931
# Name: 23, dtype: object

# %%
df.Region
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-06c91b97e334> in <module>
# ----> 1 df.Region
#
# ~\New folder\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Region'

# %%
df.to_csv('e://myfiles//ppp.csv')

# %%
pd.read_csv('e://myfiles//ppp.csv')
# Out:
#     Unnamed: 0  Sno                                    Region  Population  \
# 0            0    1                             Uttar Pradesh   199812341
# 1            1    2                               Maharashtra   112374333
# 2            2    3                                     Bihar   104099452
# 3            3    4                               West Bengal    91276115
# 4            4    5                            Madhya Pradesh    72626809
# 5            5    6                                Tamil Nadu    72147030
# 6            6    7                                 Rajasthan    68548437
# 7            7    8                                 Karnataka    61095297
# 8            8    9                                   Gujarat    60439692
# 9            9   10                            Andhra Pradesh    49577103
# 10          10   11                                    Odisha    41974218
# 11          11   12                                 Telengana    35003674
# ...
