# %%
import matplotlib.pyplot as pt
import pandas as pd

# %%
df=pd.read_csv('e://myfiles//covid2019.csv')

# %%
df.head(1
       )
# Out:
#         Date Country/Region Province/State   Lat  Long  Confirmed  Recovered  \
# 0  1/22/2020    Afghanistan            NaN  33.0  65.0        0.0        0.0
#
#    Deaths
# 0     0.0

# %%
df.columns=df.columns.str.replace('/','')

# %%
df.head(1)
# Out:
#         Date CountryRegion ProvinceState   Lat  Long  Confirmed  Recovered  \
# 0  1/22/2020   Afghanistan           NaN  33.0  65.0        0.0        0.0
#
#    Deaths
# 0     0.0

# %%
df_c=df.groupby('CountryRegion')['Recovered','Confirmed','Deaths'].max()
# Out:
# C:\Users\Mumin\New folder\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_c.head(1)
# Out:
#                Recovered  Confirmed  Deaths
# CountryRegion
# Afghanistan         10.0      273.0     6.0

# %%
df_c['Deaths'].idxmax()
# Out:
# 'Italy'

# %%
df_c['Deaths'].plot(kind='bar',figsize=(50,10))

# %%
df['Deaths']==500
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18571    False
# 18572    False
# 18573    False
# 18574    False
# 18575    False
# Name: Deaths, Length: 18576, dtype: bool

# %%
df[df['Deaths']==13915]
# Out:
#            Date CountryRegion ProvinceState   Lat  Long  Confirmed  Recovered  \
# 10727  4/2/2020         Italy           NaN  43.0  12.0   115242.0    18278.0
#
#         Deaths
# 10727  13915.0

# %%
df['Deaths'].max()
# Out:
# 13915.0

# %%
import geopandas as pf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-91e5b87efb09> in <module>
# ----> 1 import geopandas as pf
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
pip install geopandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Mumin\New' is not recognized as an internal or external command,
# operable program or batch file.
