# %%
import pandas as pd

# %%
ted=pd.read_csv('e://myfiles//ted.csv')

# %%
ted.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %%
ted.shape
# Out:
# (2550, 17)

# %%
ted.info
# Out:
# <bound method DataFrame.info of       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
ted['comments per view']=ted.comments/ted.views

# %%
ted.tail()
# Out:
#       comments                                        description  duration  \
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages         main_speaker  \
# 2545       TED2017  1496707200          4     Duarte Geraldino
# 2546       TED2017  1492992000          3  Armando Azua-Bustos
# 2547       TED2017  1492992000          1       Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2549       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# ...

# %%
ted['views per comment']=ted.views/ted.comments

# %%
ted.sort_values('views per comment').head()
# Out:
#      comments                                        description  duration  \
# 744       649  Hours before New York lawmakers rejected a key...       453
# 803       834  David Bismark demos a new system for voting th...       422
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 954      2492  Janet Echelman found her true voice as an arti...       566
#
#                      event   film_date  languages           main_speaker  \
# 744  New York State Senate  1259712000          0        Diane J. Savino
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 96                 TED2002  1012608000         42        Richard Dawkins
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 954                TED2011  1299110400         35         Janet Echelman
#
#                                                   name  num_speaker  \
# ...

# %%
ted['Date_film']=pd.to_datetime(ted.film_date,unit='s')

# %%
ted.sort_values('Date_film').head()
# Out:
#      comments                                        description  duration  \
# 686       373  In this rare clip from 1972, legendary psychia...       262
# 629       146  In this archival footage from BBC TV, celebrat...      3955
# 200        64  With surprising accuracy, Nicholas Negroponte ...      1523
# 202         9  Before he was a legend, architect Frank Gehry ...      2678
# 600       133  At the Royal Institution in 1991, Richard Dawk...      3475
#
#                    event  film_date  languages         main_speaker  \
# 686  Toronto Youth Corps   74649600          0        Viktor Frankl
# 629               BBC TV  426531600          0      Richard Feynman
# 200              TED1984  444528000         18  Nicholas Negroponte
# 202              TED1990  636422400         19          Frank Gehry
# 600    Royal Institution  693238260          0      Richard Dawkins
#
#                                               name  num_speaker  \
# ...

# %%
ted[['event','Date_film']].sample()
# Out:
#            event  Date_film
# 1236  TEDxAustin 2012-02-11

# %%
ted.Date_film.dt.year.head()
# Out:
# 0    2006
# 1    2006
# 2    2006
# 3    2006
# 4    2006
# Name: Date_film, dtype: int64

# %%
ted.event.head()
# Out:
# 0    TED2006
# 1    TED2006
# 2    TED2006
# 3    TED2006
# 4    TED2006
# Name: event, dtype: object

# %%
ted.event.str.lower().head()
# Out:
# 0    ted2006
# 1    ted2006
# 2    ted2006
# 3    ted2006
# 4    ted2006
# Name: event, dtype: object

# %%
ted.Date_film.dt.year.value_counts()
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# 2015    239
# 2014    237
# 2009    232
# 2007    114
# 2017     98
# 2008     84
# 2005     66
# 2006     50
# 2003     33
# 2004     33
# 2002     27
# 1998      6
# 2001      5
# 1983      1
# 1991      1
# 1994      1
# 1990      1
# 1984      1
# 1972      1
# Name: Date_film, dtype: int64

# %%
ted.Date_film.dt.year.value_counts().sort_index().plot()

# %%
ted.event.head()
# Out:
# 0    TED2006
# 1    TED2006
# 2    TED2006
# 3    TED2006
# 4    TED2006
# Name: event, dtype: object

# %%
ted.event.sort_index().head()
# Out:
# 0    TED2006
# 1    TED2006
# 2    TED2006
# 3    TED2006
# 4    TED2006
# Name: event, dtype: object

# %%
ted.groupby('event').views.mean().head()
# Out:
# event
# AORN Congress                  149818.0
# Arbejdsglaede Live             971594.0
# BBC TV                         521974.0
# Bowery Poetry Club             676741.0
# Business Innovation Factory    304086.0
# Name: views, dtype: float64
